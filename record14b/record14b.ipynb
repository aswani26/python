# %%
from package3 import rect1
from package3 import cir1
from package3.graphics import cuboid
from package3.graphics import sphere

while(1):
    print("1. Rectangle\n2. Circle\n3. Cuboid\n 4. Sphere\n 5. Exit")
    ch=int(input("Enter your choice: "))
    if ch==1:
        l=int(input("Enter length: "))
        b=int(input("Enter breadth: "))
        print("Area of rectangle",rectangle.rectare(l,b))
        print("Perimeter of rectangle",rectangle.rectperi(l,b))
    elif ch==2:
        r=int(input("Enter radius: "))
        print("Area of circle",circle.circleare(r))
        print("Perimeter of circle",circle.circleperi(r))
    elif ch==3:
        l = int(input("Enter length: "))
        b = int(input("Enter breadth: "))
        h= int(input("Enter height: "))
        print("Area of cuboid",cuboid.cuboidarea(l,b,h))
        print("Perimeter of circle",cuboid.cuboidperi(l,b,h))
    elif ch==4:
        r=int(input("Enter radius: "))
        print("Area of Sphere",sphere.spherearea(r))
        print("Perimeter of sphere",sphere.sphereperi(r))
    else:
        print("Exiting...")
        break
# Out:
# 1. Rectangle
# 2. Circle
# 3. Cuboid
#  4. Sphere
#  5. Exit
# Enter your choice: 1
# Enter length: 2
# Enter breadth: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#      10     l=int(input("Enter length: "))
#      11     b=int(input("Enter breadth: "))
# ---> 12     print("Area of rectangle",rectangle.rectare(l,b))
#      13     print("Perimeter of rectangle",rectangle.rectperi(l,b))
#      14 elif ch==2:
#
# NameError: name 'rectangle' is not defined
