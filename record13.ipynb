# %%
# Accept a list of words separated by spaces
words = input("Enter a list of words: ").split(",")
def length(words):
    result = max(len(w) for w in words)  
    return result

print("Length of the largest word is:", length(words))
# Out:
# Enter a list of words: sinu,manu,aswani
# Length of the largest word is: 6

# %%
#display pattern
n=int(input("enter number of stars:"))
def star(n):
    for i in range(1,n+1):
        for j in range(i):
            print("*",end=" ")
        print()
    for i in range(n-1,0,-1):
        for j in range(i):
            print("*",end=" ")
        print()
star(n)
# Out:
# enter number of stars:5
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
#find factors of a number
num=int(input("enetr a number"))
def factor(num):
    return[i for i in range(1,num+1) if num%i ==0]
print("factor of number",num,"are",factor(num))
# Out:
# enetr a number4
# factor of number 4 are [1, 2, 4]

# %%
#find area using lambda function
square=lambda a:a*a
rectangle=lambda l,w:l*w
trianlge=lambda b,h:0.5*b*h

a=int(input("enter the side of the sqaure:"))
print("area of the square:",square(a))
l=int(input("enter the length of the rectangle:"))
w=int(input("enter the width of the rectangle:"))
print("area of the square:",rectangle(l,w))

b=int(input("enter the base of the triangle:"))
h=int(input("enter the base of the triangle:"))
print("area of the square:",trianlge(b,h))
# Out:
# enter the side of the sqaure:2
# area of the square: 4
# enter the length of the rectangle:4
# enter the width of the rectangle:3
# area of the square: 12
# enter the base of the triangle:2
# enter the base of the triangle:6
# area of the square: 6.0
